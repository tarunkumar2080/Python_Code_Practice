# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)

# %%
df1['B'].hist()

# %%
df1['B'].plot(kind = 'hist', bins = 40)

# %%
df1['A'].plot.hist()

# %%
df2.head()  #Non-time series
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
#Area Plot
df2.plot.area()

# %%
df2.plot.area(alpha = 0.5)

# %%
df2.plot.bar() #Bar plot is preferred in case of categorical variables

# %%
#Stacked Bar Plot

df2.plot.bar(stacked = True)

# %%
# Line Plot 

df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x = 'A', y ='B')

# %%
#df1.plot.line(x = df1.index, y = 'A')

# %%
df1.plot.scatter(x = 'A', y ='B', c='C') # 3 dimensional plot

# %%
df1.plot.scatter(x = 'A', y ='B', c='C', cmap = 'coolwarm')

# %%
# Plotting by size
df1.plot.scatter(x = 'A', y ='B', c='C', s = df1['C']*100, cmap = 'coolwarm')

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns = ['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.931909  0.778586
# 1  0.788379  0.096231
# 2 -0.538092  0.042286
# 3 -0.127457 -0.020755
# 4  0.926301 -1.088559

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize = 20)

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize = 20, cmap = 'coolwarm')

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()

# %%
df2.plot.density()
